# %%
include("copper.jl")

# %% [markdown]
# These are the results for Example 2. I will do the examples from the paper with both the two stage algorithm and algorithm 1. I will do both preconditioned and unpreconditioned cases.

# %%
tau_test_copper(15; algfun=alg1e2)
# Out:
# Ex 2; Precond = false; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
tau_test_copper(15; algfun=alg1e2, precond=true, maxit=3000)
# Out:
# Ex 2; Precond = true; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(15; algfun=alg1e2, maxit=3000, tau=.05)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.05; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(15; algfun=alg1e2, maxit=1500, tau=.05)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.05; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Now for the two-stage method.

# %%
tau_test_copper(15; algfun=alg2ge2)
# Out:
# Ex 2; Precond = false; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(15; algfun=alg2ge2,maxit=300)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
tau_test_copper(15; algfun=alg2ge2, precond=true)
# Out:
# Ex 2; Precond = true; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(15; algfun=alg2ge2,maxit=100, precond=true)
# Out:
# Ex 2; Precond = true; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)
