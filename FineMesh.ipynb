# %%
include("copper.jl")
# Out:
#     CondaPkg Found dependencies: /Users/ctk/.julia/packages/CondaPkg/8GjrP/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/ctk/.julia/packages/PythonCall/83z4q/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/ctk/.julia/packages/PythonPlot/oS8x4/CondaPkg.toml
#     CondaPkg Dependencies already up to date

# %%
tau_test_copper(31; algfun=alg1e2)
# Out:
# Ex 2; Precond = false; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(31; algfun=alg1e2)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(31; algfun=alg2ge2, maxit=500, precond=true)
# Out:
# Ex 2; Precond = true; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
alpha_test_copper(31; algfun=alg2ge2, maxit=5000, precond=false, tau=.05)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.05; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)
