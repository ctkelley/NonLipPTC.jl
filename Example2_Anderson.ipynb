# %%
include("copper.jl")

# %% [markdown]
# This notebook has the AA results for Example 2. First Alg 1.

# %%
aa_test_copper(15; maxit=200, GF=GF1e2!)
# Out:
# Ex 2; Precond = true; Fixed alpha = 0.5; vary tau
# Failure to converge after 200 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
aa_alpha_copper(15; maxit=200, GF=GF1e2!)
# Out:
# Ex 2; Precond = true; Fixed tau = 0.1; vary alpha
# Failure to converge after 200 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
aa_test_copper(15; maxit=2000, GF=GF1e2!, precond=false)
# Out:
# Ex 2; Precond = false; Fixed alpha = 0.5; vary tau
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
aa_alpha_copper(15; maxit=1000, GF=GF1e2!, precond=false)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.1; vary alpha
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Now the two-stage algorithm

# %%
aa_test_copper(15; maxit=200, GF=GF2e2!)
# Out:
# Ex 2; Precond = true; Fixed alpha = 0.5; vary tau
# Failure to converge after 200 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
aa_alpha_copper(15; maxit=200, GF=GF2e2!)
# Out:
# Ex 2; Precond = true; Fixed tau = 0.1; vary alpha
# Failure to converge after 200 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %% [markdown]
# The iteration is unstable for the large value of $\tau$

# %%
aa_test_copper(15; maxit=1000, GF=GF2e2!, precond=false)
# Out:
# Ex 2; Precond = false; Fixed alpha = 0.5; vary tau
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)

# %%
aa_alpha_copper(15; maxit=1000, GF=GF2e2!, precond=false)
# Out:
# Ex 2; Precond = false; Fixed tau = 0.1; vary alpha
# Failure to converge after 1000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 1 Axes>)
