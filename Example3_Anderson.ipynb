# %%
include("copper.jl")

# %% [markdown]
# We run the tests for AA for varying $\tau$. For AA changing $\alpha$ also makes a difference. First the results for Algorithm 1.

# %%
aa_test_copper(31; GF=GF1e3!,maxit=100)
# Out:
# Ex 3; Precond = true; Fixed alpha = 0.5; vary tau
# Failure to converge after 100 iterations for m=1 in aasol.jl
# Failure to converge after 100 iterations for m=1 in aasol.jl
# Failure to converge after 100 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %% [markdown]
# Without preconditioning we have to reduce $\tau$ to avoid divergence.

# %%
aa_test_copper(31; GF=GF1e3!,maxit=10000, tauvec=[.02, .01, .005, .001], precond=false)
# Out:
# Ex 3; Precond = false; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %%
aa_alpha_copper(31; GF=GF1e3!)
# Out:
# Ex 3; Precond = true; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %%
aa_alpha_copper(31; GF=GF1e3!,maxit=2000, tau=.01, precond=false)
# Out:
# Ex 3; Precond = false; Fixed tau = 0.01; vary alpha
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %% [markdown]
# Now for the look-ahead method. I saw divergence for some cases where Alg 1 worked well and used smaller values of $\tau$.

# %%
aa_test_copper(31; GF=GF2e3!,maxit=100)
# Out:
# Ex 3; Precond = true; Fixed alpha = 0.5; vary tau
# Failure to converge after 100 iterations for m=1 in aasol.jl
# Failure to converge after 100 iterations for m=1 in aasol.jl
# Failure to converge after 100 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %%
aa_test_copper(31; GF=GF2e3!,maxit=10000, tauvec=[.005, .002, .001, .0005], precond=false)
# Out:
# Ex 3; Precond = false; Fixed alpha = 0.5; vary tau
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %%
aa_alpha_copper(31; GF=GF2e3!)
# Out:
# Ex 3; Precond = true; Fixed tau = 0.1; vary alpha
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)

# %%
aa_alpha_copper(31; GF=GF2e3!,maxit=2000, tau=.001, precond=false)
# Out:
# Ex 3; Precond = false; Fixed tau = 0.001; vary alpha
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# Failure to converge after 2000 iterations for m=1 in aasol.jl
# PythonPlot.Figure(<py Figure size 640x480 with 2 Axes>)
